# %% [markdown]
# Name: Aditya Kamath
#
# Btech EXTC 3rd Year
#
# Experiment no: 8
#
# Date of Performance: 19/03/21

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import cv2

# %% [markdown]
# Read the Image

# %%
img= cv2.imread("/content/house.tif",0) #Read the image
plt.imshow(img, cmap="gray", vmin=0, vmax=255)
m,n = img.shape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Horizontal edge detection

# %%
#Detect horizontal edges using in built convolution function
sobel_h= np.array([[-1,-2,-1], [0,0,0], [1,2,1]])
img_h= signal.convolve(img,sobel_h,mode='full')
plt.imshow(img_h,cmap="gray", vmin=0, vmax=255)

# %%
#Detect horizontal edges without using in built convolution function
mask= np.array([[-1,-2,-1], [0,0,0], [1,2,1]])
img_new_h=np.zeros([m,n])
for i in range(1,m-1):
    for j in range(1,n-1):
        temp= img[i-1,j-1]*mask[0,0]+img[i-1,j]*mask[0,1]+img[i-1,j+1]*mask[0,2]+img[i,j-1]*mask[1,0]+img[i,j]*mask[1,1]+img[i,j+1]*mask[1,2]+img[i+1,j-1]*mask[2,0]+img[i+1,j]*mask[2,1]+img[i+1,j+1]*mask[2,2]
      
        img_new_h[i,j]=temp

plt.imshow(img_new_h, cmap="gray", vmin=0)

# %%
f = 0
for k in range(4):
  M = [np.array([[-1,-2,-1], [0,0,0], [1,2,1]]),
       np.array([[-1,-4,-1], [0,0,0], [1,4,1]]),
       np.array([[-1,-8,-1], [0,0,0], [1,8,1]]),
       np.array([[-1,-10,-1], [0,0,0], [1,10,1]])]

  mask = M[k]
  img_new_h=np.zeros([m,n])
  for i in range(1,m-1):
      for j in range(1,n-1):
          temp= img[i-1,j-1]*mask[0,0]+img[i-1,j]*mask[0,1]+img[i-1,j+1]*mask[0,2]+img[i,j-1]*mask[1,0]+img[i,j]*mask[1,1]+img[i,j+1]*mask[1,2]+img[i+1,j-1]*mask[2,0]+img[i+1,j]*mask[2,1]+img[i+1,j+1]*mask[2,2]
        
          img_new_h[i,j]=temp

  plt.figure(figsize=(30,30))
  plt.subplot(4,1,f+1)
  plt.title("Image with Matrix ={} ".format(mask))
  plt.imshow(img_new_h,cmap="gray",vmin=0,vmax=255)
  f = f+1

# %% [markdown]
# # Vertical edge detection

# %%
#Detect vertical edges using inbuilt function for convolution
sobel_v= np.array([[-1,0,1], [-2,0,2], [-1,0,1]])
img_v= signal.convolve(img,sobel_v,mode='same')
plt.imshow(img_v,cmap="gray", vmin=0, vmax=255)

# %%
#Detect vertical edges without using in built convolution function
mask_v= np.array([[-1,0,1], [-2,0,2], [-1,0,1]])
img_new_v=np.zeros([m,n])
for i in range(1,m-1):
    for j in range(1,n-1):
        temp= img[i-1,j-1]*mask_v[0,0]+img[i-1,j]*mask_v[0,1]+img[i-1,j+1]*mask_v[0,2]+img[i,j-1]*mask_v[1,0]+img[i,j]*mask_v[1,1]+img[i,j+1]*mask_v[1,2]+img[i+1,j-1]*mask_v[2,0]+img[i+1,j]*mask_v[2,1]+img[i+1,j+1]*mask_v[2,2]
      
        img_new_v[i,j]=temp

plt.imshow(img_new_v, cmap="gray", vmin=0)

# %%
f = 0
for k in range(4):
  M = [np.array([[-1,0,1], [-2,0,2], [-1,0,1]]),
       np.array([[-1,0,1], [-4,0,4], [-1,0,1]]),
       np.array([[-1,0,1], [-8,0,8], [-1,0,1]]),
       np.array([[-1,0,1], [-10,0,10], [-1,0,1]])]

  mask = M[k]
  img_new_h=np.zeros([m,n])
  for i in range(1,m-1):
      for j in range(1,n-1):
          temp= img[i-1,j-1]*mask[0,0]+img[i-1,j]*mask[0,1]+img[i-1,j+1]*mask[0,2]+img[i,j-1]*mask[1,0]+img[i,j]*mask[1,1]+img[i,j+1]*mask[1,2]+img[i+1,j-1]*mask[2,0]+img[i+1,j]*mask[2,1]+img[i+1,j+1]*mask[2,2]
        
          img_new_h[i,j]=temp

  plt.figure(figsize=(30,30))
  plt.subplot(4,1,f+1)
  plt.title("Image with Matrix ={} ".format(mask))
  plt.imshow(img_new_h,cmap="gray",vmin=0,vmax=255)
  f = f+1

# %% [markdown]
# # Horizontal + Vertical edge

# %%
#Detecting vertical and horizontal edges
img_hv= img_h+img_v
plt.imshow(img_hv, cmap="gray", vmin=0, vmax=255)

# %% [markdown]
# # Diagonal edge detection

# %%
# Detecting Diagonal with inbuilt convolve
sobel_d= np.array([[0,1,2], [-1,0,1], [-2,-1,0]])
img_d= signal.convolve(img,sobel_d,mode='same')
plt.imshow(img_d, cmap="gray", vmin=0, vmax=255)

# %%
# Detecting Diagonal without inbuilt convolve function
mask_d= np.array([[0,1,2], [-1,0,1], [-2,-1,0]])
img_new_d=np.zeros([m,n])
for i in range(1,m-1):
    for j in range(1,n-1):
        temp= img[i-1,j-1]*mask_d[0,0]+img[i-1,j]*mask_d[0,1]+img[i-1,j+1]*mask_d[0,2]+img[i,j-1]*mask_d[1,0]+img[i,j]*mask_d[1,1]+img[i,j+1]*mask_d[1,2]+img[i+1,j-1]*mask_d[2,0]+img[i+1,j]*mask_d[2,1]+img[i+1,j+1]*mask_d[2,2]
      
        img_new_d[i,j]=temp

plt.imshow(img_new_d, cmap="gray", vmin=0)

# %% [markdown]
# # Horizontal + Vertical + Diagonal edge

# %%
#Horizontal, vertical and diagonal edges
img_hvd= img_h+img_v+img_d
plt.imshow(img_hvd, cmap="gray", vmin=0, vmax=255)

# %% [markdown]
# # ALL Edge Detection

# %%
plt.figure(figsize=(30,30))
plt.subplot(7,7,1)
plt.imshow(img,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,2)
plt.imshow(img_h,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,3)
plt.imshow(img_h1,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,4)
plt.imshow(img_hvd,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,5)
plt.imshow(img_hvd1,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,6)
plt.imshow(img_c,cmap="gray", vmin=0, vmax=255)
plt.subplot(7,7,7)
plt.imshow(img_r,cmap="gray", vmin=0, vmax=255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b7564d8d664a> in <module>()
#       7 #plt.imshow(img_h1,cmap="gray", vmin=0, vmax=255)
#       8 plt.subplot(7,7,4)
# ----> 9 plt.imshow(img_hvd,cmap="gray", vmin=0, vmax=255)
#      10 plt.subplot(7,7,5)
#      11 plt.imshow(img_hvd1,cmap="gray", vmin=0, vmax=255)
#
# NameError: name 'img_hvd' is not defined

# %% [markdown]
# # Other Inbuilt Functions

# %%
from PIL import Image, ImageFilter 
  
img =  cv2.imread('/content/house.tif',0)
# Calculating Edges using the passed laplican Kernel 
final = img.filter(ImageFilter.Kernel((3, 3), (-1, -1, -1, -1, 8,-1, -1, -1, -1), 1, 0)) 
plt.imshow(final,cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ff37c36587aa> in <module>()
#       5
#       6 # Calculating Edges using the passed laplican Kernel
# ----> 7 final = img.Filter(ImageFilter.Kernel((3, 3), (-1, -1, -1, -1, 8,-1, -1, -1, -1), 1, 0))
#       8 plt.imshow(final,cmap = 'gray')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Filter'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# loading image

img0 = cv2.imread('/content/house.tif',0)

# convolute with proper kernels
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([],vmin = 0, vmax = 255)
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([],vmin = 0, vmax = 255)
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([],vmin = 0, vmax = 255)
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([],vmin = 0, vmax = 255)

plt.show()

# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline

#read the image
image = cv2.imread('/content/house.tif',0) 
#calculate the edges using Canny edge algorithm
edges = cv2.Canny(image,100,100,0) 
#plot the edges
plt.imshow(edges)
